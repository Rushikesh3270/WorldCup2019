# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
players=pd.read_csv('WC_players.csv')
players
# Out:
#                    Player      ID      Country
# 0       Gulbadin Naib (c)  352048  Afghanistan
# 1        Rashid Khan (vc)  793463  Afghanistan
# 2              Aftab Alam  440963  Afghanistan
# 3           Asghar Afghan  320652  Afghanistan
# 4           Dawlat Zadran  516561  Afghanistan
# ..                    ...     ...          ...
# 147          Ashley Nurse  315594   WestIndies
# 148  Nicholas Pooran (wk)  604302   WestIndies
# 149           Kemar Roach  230553   WestIndies
# 150         Andre Russell  276298   WestIndies
# 151         Oshane Thomas  914567   WestIndies
#
# [152 rows x 3 columns]

# %%
odi_total=pd.read_csv('ODI_Match_Totals.csv')
odi_total
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 0            412    250   48.3  5.15     NaN     1    won      v India
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 2            413    157   48.5  3.21   168.0     2   lost      v India
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 4            117    198   40.0  4.95   306.0     2   lost  v Australia
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1291         549  340/7   50.0  6.80     NaN     1   lost    v England
# 1292         979  341/7   49.3  6.88   341.0     2    won   v Pakistan
# 1293        1296  120/8   33.0  3.63   211.0     2      -    v Ireland
# 1294         550  193/6   31.5  6.06   352.0     2      -    v England
# 1295         980  351/9   50.0  7.02     NaN     1      -   v Pakistan
#
#           Ground   Start Date    Match_ID      Country  Country_ID
# ...

# %%
data=pd.merge(players,odi_total)
data
# Out:
#                   Player      ID      Country  Unnamed: 0  Score  Overs   RPO  \
# 0      Gulbadin Naib (c)  352048  Afghanistan        1207  203/3   33.5  6.00
# 1      Gulbadin Naib (c)  352048  Afghanistan        1208  261/5   48.4  5.36
# 2      Gulbadin Naib (c)  352048  Afghanistan        1209   95/2   17.5  5.32
# 3      Gulbadin Naib (c)  352048  Afghanistan        1210   96/3   20.5  4.60
# 4      Gulbadin Naib (c)  352048  Afghanistan        1211    176   47.2  3.71
# ...                  ...     ...          ...         ...    ...    ...   ...
# 17766      Oshane Thomas  914567   WestIndies         112  381/3   50.0  7.62
# 17767      Oshane Thomas  914567   WestIndies         113  261/9   50.0  5.22
# 17768      Oshane Thomas  914567   WestIndies         114  331/5   47.5  6.91
# 17769      Oshane Thomas  914567   WestIndies         115  247/9   50.0  4.94
# 17770      Oshane Thomas  914567   WestIndies         116  152/1   24.0  6.33
#
# ...

# %%
data.shape
# Out:
# (17771, 15)

# %%
data.head()
# Out:
#               Player      ID      Country  Unnamed: 0  Score  Overs   RPO  \
# 0  Gulbadin Naib (c)  352048  Afghanistan        1207  203/3   33.5  6.00
# 1  Gulbadin Naib (c)  352048  Afghanistan        1208  261/5   48.4  5.36
# 2  Gulbadin Naib (c)  352048  Afghanistan        1209   95/2   17.5  5.32
# 3  Gulbadin Naib (c)  352048  Afghanistan        1210   96/3   20.5  4.60
# 4  Gulbadin Naib (c)  352048  Afghanistan        1211    176   47.2  3.71
#
#    Target  Inns Result  Opposition    Ground   Start Date    Match_ID  \
# 0   200.0     2    won  v Scotland   Sharjah   6 Mar 2013  ODI # 3341
# 1   260.0     2    won  v Scotland   Sharjah   8 Mar 2013  ODI # 3342
# 2    90.0     2    won     v Kenya   Sharjah   2 Oct 2013  ODI # 3417
# 3    94.0     2    won     v Kenya   Sharjah   4 Oct 2013  ODI # 3418
# 4   249.0     2   lost  v Pakistan  Fatullah  27 Feb 2014  ODI # 3475
#
#    Country_ID
# 0          40
# 1          40
# 2          40
# 3          40
# 4          40

# %%
data.tail()
# Out:
#               Player      ID     Country  Unnamed: 0  Score  Overs   RPO  \
# 17766  Oshane Thomas  914567  WestIndies         112  381/3   50.0  7.62
# 17767  Oshane Thomas  914567  WestIndies         113  261/9   50.0  5.22
# 17768  Oshane Thomas  914567  WestIndies         114  331/5   47.5  6.91
# 17769  Oshane Thomas  914567  WestIndies         115  247/9   50.0  4.94
# 17770  Oshane Thomas  914567  WestIndies         116  152/1   24.0  6.33
#
#        Target  Inns Result    Opposition             Ground   Start Date  \
# 17766     NaN     1    won     v Ireland             Dublin   5 May 2019
# 17767     NaN     1   lost  v Bangladesh             Dublin   7 May 2019
# 17768   328.0     2    won     v Ireland  Dublin (Malahide)  11 May 2019
# 17769     NaN     1   lost  v Bangladesh  Dublin (Malahide)  13 May 2019
# 17770     NaN     1   lost  v Bangladesh  Dublin (Malahide)  17 May 2019
#
#          Match_ID  Country_ID
# 17766  ODI # 4128           4
# ...

# %%
data.columns
# Out:
# Index(['Player', 'ID', 'Country', 'Unnamed: 0', 'Score', 'Overs', 'RPO',
#        'Target', 'Inns', 'Result', 'Opposition', 'Ground', 'Start Date',
#        'Match_ID', 'Country_ID'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17771 entries, 0 to 17770
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      17771 non-null  object
#  1   ID          17771 non-null  int64
#  2   Country     17771 non-null  object
#  3   Unnamed: 0  17771 non-null  int64
#  4   Score       17771 non-null  object
#  5   Overs       17771 non-null  float64
#  6   RPO         17771 non-null  object
#  7   Target      8532 non-null   float64
#  8   Inns        17771 non-null  int64
#  9   Result      17771 non-null  object
#  10  Opposition  17771 non-null  object
#  11  Ground      17771 non-null  object
#  12  Start Date  17771 non-null  object
#  13  Match_ID    17771 non-null  object
#  14  Country_ID  17771 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 2.2+ MB

# %%
data.isnull().sum()
# Out:
# Player           0
# ID               0
# Country          0
# Unnamed: 0       0
# Score            0
# Overs            0
# RPO              0
# Target        9239
# Inns             0
# Result           0
# Opposition       0
# Ground           0
# Start Date       0
# Match_ID         0
# Country_ID       0
# dtype: int64

# %%
data.describe()
# Out:
#                  ID    Unnamed: 0         Overs       Target          Inns  \
# count  1.777100e+04  17771.000000  17771.000000  8532.000000  17771.000000
# mean   3.478256e+05    653.464971     43.190400   253.577121      1.463902
# std    2.402820e+05    394.130253     10.485023    70.326994      0.530212
# min    5.334000e+03      1.000000      0.000000    68.000000      0.000000
# 25%    2.277600e+05    295.000000     40.200000   207.750000      1.000000
# 50%    3.187880e+05    713.000000     48.200000   258.000000      1.000000
# 75%    4.819790e+05   1009.000000     50.000000   303.000000      2.000000
# max    1.158100e+06   1296.000000     50.000000   482.000000      2.000000
#
#          Country_ID
# count  17771.000000
# mean       8.849643
# std       10.758285
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        8.000000
# max       40.000000

# %%
data.corr()
# Out:
#                   ID  Unnamed: 0     Overs    Target      Inns  Country_ID
# ID          1.000000   -0.060074  0.015706 -0.006632  0.008643    0.151908
# Unnamed: 0 -0.060074    1.000000  0.028541 -0.078187 -0.019585    0.428116
# Overs       0.015706    0.028541  1.000000  0.580588 -0.110921    0.015713
# Target     -0.006632   -0.078187  0.580588  1.000000       NaN   -0.102439
# Inns        0.008643   -0.019585 -0.110921       NaN  1.000000   -0.025221
# Country_ID  0.151908    0.428116  0.015713 -0.102439 -0.025221    1.000000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Target']=data['Target'].fillna(method='pad')

# %%
data
# Out:
#                   Player      ID      Country  Unnamed: 0  Score  Overs   RPO  \
# 0      Gulbadin Naib (c)  352048  Afghanistan        1207  203/3   33.5  6.00
# 1      Gulbadin Naib (c)  352048  Afghanistan        1208  261/5   48.4  5.36
# 2      Gulbadin Naib (c)  352048  Afghanistan        1209   95/2   17.5  5.32
# 3      Gulbadin Naib (c)  352048  Afghanistan        1210   96/3   20.5  4.60
# 4      Gulbadin Naib (c)  352048  Afghanistan        1211    176   47.2  3.71
# ...                  ...     ...          ...         ...    ...    ...   ...
# 17766      Oshane Thomas  914567   WestIndies         112  381/3   50.0  7.62
# 17767      Oshane Thomas  914567   WestIndies         113  261/9   50.0  5.22
# 17768      Oshane Thomas  914567   WestIndies         114  331/5   47.5  6.91
# 17769      Oshane Thomas  914567   WestIndies         115  247/9   50.0  4.94
# 17770      Oshane Thomas  914567   WestIndies         116  152/1   24.0  6.33
#
# ...

# %%
data.corr()
# Out:
#                   ID  Unnamed: 0     Overs    Target      Inns  Country_ID
# ID          1.000000   -0.060074  0.015706 -0.011139  0.008643    0.151908
# Unnamed: 0 -0.060074    1.000000  0.028541 -0.063821 -0.019585    0.428116
# Overs       0.015706    0.028541  1.000000  0.286388 -0.110921    0.015713
# Target     -0.011139   -0.063821  0.286388  1.000000 -0.026152   -0.129375
# Inns        0.008643   -0.019585 -0.110921 -0.026152  1.000000   -0.025221
# Country_ID  0.151908    0.428116  0.015713 -0.129375 -0.025221    1.000000

# %%
data.isnull().sum()
# Out:
# Player        0
# ID            0
# Country       0
# Unnamed: 0    0
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Country_ID    0
# dtype: int64

# %% [markdown]
# # Indian Team Data

# %%
Indian_players=players[players['Country']=="India"]

# %%
Indian_players
# Out:
#                Player      ID Country
# 61    Virat Kohli (c)  253802   India
# 62  Rohit Sharma (vc)   34102   India
# 63     Shikhar Dhawan   28235   India
# 64        K. L. Rahul  422108   India
# 65      Vijay Shankar  477021   India
# 66      MS Dhoni (wk)   28081   India
# 67       Kedar Jadhav  290716   India
# 68     Dinesh Karthik   30045   India
# 69   Yuzvendra Chahal  430246   India
# 70      Kuldeep Yadav  559235   India
# 71  Bhuvneshwar Kumar  326016   India
# 72     Jasprit Bumrah  625383   India
# 73      Hardik Pandya  625371   India
# 74    Ravindra Jadeja  234675   India
# 75     Mohammed Shami  481896   India

# %%
India = odi_total[odi_total['Country']=='India']

# %%
India_win = India[India['Result']=='won']

# %%
India_win['Opposition'].value_counts()
# Out:
# v Sri Lanka       15
# v West Indies     13
# v Zimbabwe        12
# v Australia       12
# v South Africa    10
# v England         10
# v New Zealand      9
# v Bangladesh       8
# v Pakistan         6
# v U.A.E.           1
# v Ireland          1
# v Afghanistan      1
# v Hong Kong        1
# Name: Opposition, dtype: int64

# %%
plt.figure(figsize=(10,6))
India_win['Opposition'].value_counts().plot(kind='bar')
plt.title('Most wins Against Respective Teams',fontsize=20)
plt.xlabel('Team Names')
plt.ylabel('Wins');

# %%
India_loss = India[India['Result']=='lost']

# %%
India_loss['Opposition'].value_counts()
# Out:
# v Australia       13
# v England          8
# v New Zealand      8
# v South Africa     6
# v West Indies      5
# v Sri Lanka        4
# v Pakistan         3
# v Bangladesh       2
# Name: Opposition, dtype: int64

# %%
plt.figure(figsize=(9,9))
India_loss['Opposition'].value_counts().plot(kind='pie',autopct='%0.1f%%');

# %%
India[India.Target>300]
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 6            682  316/9   50.0  6.32   326.0     2   lost       v England
# 115          693    187   44.5  4.17   349.0     2   lost     v Sri Lanka
# 164          702    232   49.4  4.67   305.0     2   lost     v Australia
# 166          703  362/1   43.3  8.32   360.0     2    won     v Australia
# 174          706  351/4   49.3  7.09   351.0     2    won     v Australia
# 211          711    217   41.0  5.29   359.0     2   lost  v South Africa
# 247          716  314/9   50.0  6.28   315.0     2   tied   v New Zealand
# 253          718    216   49.4  4.34   304.0     2   lost   v New Zealand
# 355          730    197   41.0  4.80   322.0     2   lost   v West Indies
# 537          749    233   46.5  4.97   329.0     2   lost     v Australia
# 559          750    228   46.0  4.95   308.0     2   lost    v Bangladesh
# 610          756  298/7   50.0  5.96   304.0     2   lost  v South Africa
# ...

# %%
India[India.Target>300].Result.value_counts().plot(kind='bar')
plt.title('Matches Won While Chasing 300+ Score');

# %%
India.Ground.value_counts()
# Out:
# Harare                9
# Dhaka                 8
# Dubai (DSC)           6
# Birmingham            5
# Melbourne             5
# Ranchi                5
# Port of Spain         5
# Mohali                5
# The Oval              4
# Pune                  4
# Delhi                 4
# Hamilton              4
# Dharamsala            4
# Perth                 4
# Visakhapatnam         4
# Sydney                4
# Kolkata               4
# Kochi                 3
# Kanpur                3
# Cardiff               3
# Kingston              3
# Centurion             3
# Nagpur                3
# Chennai               2
# Johannesburg          2
# Hyderabad (Deccan)    2
# Nottingham            2
# Bengaluru             2
# Durban                2
# Mount Maunganui       2
# Fatullah              2
# Pallekele             2
# Mumbai                2
# Indore                2
# Brisbane              2
# Napier                2
# Bulawayo              2
# Adelaide              2
# ...

# %%
plt.figure(figsize=(17,7))
India.Ground.value_counts().plot(kind='bar')
plt.title('Most Matches Played On Each Venue',fontsize=20)
plt.xlabel('Venue',fontsize=15);

# %%
India[India.Target>400].Result.value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(9,6))
India[India.Result=='won'].Ground.value_counts().plot(kind='bar')
plt.title('Most Wins On Each Venus')
plt.xlabel('Venus');

# %% [markdown]
# # Australia Team Data

# %%
Australia_players=players[players['Country']=="Australia"]

# %%
Australia_players
# Out:
#                  Player      ID    Country
# 15      Aaron Finch (c)    5334  Australia
# 16     Pat Cummins (vc)  489889  Australia
# 17      Alex Carey (wk)  326434  Australia
# 18    Jason Behrendorff  272477  Australia
# 19  Nathan Coulter-Nile  261354  Australia
# 20        Usman Khawaja  215155  Australia
# 21          Nathan Lyon  272279  Australia
# 22          Shaun Marsh    6683  Australia
# 23        Glenn Maxwell  325026  Australia
# 24      Jhye Richardson  774223  Australia
# 25      Kane Richardson  272262  Australia
# 26          Steve Smith  267192  Australia
# 27       Mitchell Starc  311592  Australia
# 28       Marcus Stoinis  325012  Australia
# 29         David Warner  219889  Australia
# 30           Adam Zampa  379504  Australia

# %%
Australia = odi_total[odi_total['Country']=='Australia']

# %%
Australia
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 5           1076  305/5   50.0  6.10     NaN     1    won  v Sri Lanka
# 9           1077    170   46.5  3.62     NaN     1   lost  v Sri Lanka
# 13          1078     74   26.4  2.77     NaN     1   lost  v Sri Lanka
# 19          1079  222/9   50.0  4.44     NaN     1    n/r  v Sri Lanka
# 23          1080  247/5   50.0  4.94     NaN     1    won  v Sri Lanka
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1265        1202  281/2   49.0  5.73   281.0     2    won   v Pakistan
# 1267        1203  285/2   47.5  5.95   285.0     2    won   v Pakistan
# 1269        1204  266/6   50.0  5.32     NaN     1    won   v Pakistan
# 1271        1205  277/7   50.0  5.54     NaN     1    won   v Pakistan
# 1273        1206  327/7   50.0  6.54     NaN     1    won   v Pakistan
#
#            Ground   Start Date    Match_ID    Country  Country_ID
# ...

# %%
Australia_win = Australia[Australia['Result']=='won']

# %%
plt.figure(figsize=(7,5))
Australia_win['Opposition'].value_counts().plot(kind='bar')
plt.title('Most wins Against Respective Teams',fontsize=20)
plt.xlabel('Team Names')
plt.ylabel('Wins');

# %%
Australia_loss = Australia[Australia['Result']=='lost']

# %%
Australia_loss['Opposition'].value_counts()
# Out:
# v England         15
# v India           12
# v South Africa    11
# v New Zealand      5
# v Sri Lanka        4
# v West Indies      1
# v Pakistan         1
# v Zimbabwe         1
# Name: Opposition, dtype: int64

# %%
plt.figure(figsize=(7,7))
Australia_loss['Opposition'].value_counts().plot(kind='pie',autopct='%0.1f%%');

# %%
Australia[Australia.Target>200]
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 37          1084  221/5   44.5  4.92   221.0     2    won   v West Indies
# 85          1086  221/9   50.0  4.42   270.0     2   lost       v England
# 103         1088    233   42.3  5.48   254.0     2   lost     v Sri Lanka
# 169         1096  304/6   49.3  6.14   304.0     2    won         v India
# 183         1099    326   45.1  7.21   384.0     2   lost         v India
# 235         1100  270/4   45.4  5.91   270.0     2    won       v England
# 237         1101  301/9   49.3  6.08   301.0     2    won       v England
# 241         1102  244/3   40.0  6.10   244.0     2    won       v England
# 245         1103    259   47.4  5.43   317.0     2   lost       v England
# 357         1111  217/5   43.2  5.00   216.0     2    won      v Pakistan
# 387         1116  268/7   49.0  5.46   268.0     2    won  v South Africa
# 390         1117  275/8   47.1  5.83   275.0     2    won  v South Africa
# ...

# %%
Australia[Australia.Target>200].Result.value_counts()
# Out:
# won     24
# lost    19
# n/r      1
# Name: Result, dtype: int64

# %%
plt.figure(figsize=(7,7))
Australia[Australia.Target>200].Result.value_counts().plot(kind='bar')
plt.title('Matches Won While Chasing 200+ Score');

# %%
Australia.Ground.value_counts()
# Out:
# Sydney                13
# Melbourne             12
# Perth                 11
# Adelaide               7
# Birmingham             5
# Harare                 5
# Brisbane               5
# Manchester             4
# Hobart                 4
# Canberra               4
# The Oval               3
# Dubai (DSC)            3
# Sharjah                3
# Nagpur                 3
# Bridgetown             3
# Auckland               3
# Cardiff                2
# Dambulla               2
# Bengaluru              2
# Hamilton               2
# Mohali                 2
# Ranchi                 2
# Colombo (RPS)          2
# Abu Dhabi              2
# Southampton            2
# Providence             2
# Basseterre             2
# Durban                 1
# Jaipur                 1
# Edinburgh              1
# Johannesburg           1
# Indore                 1
# Hyderabad (Deccan)     1
# Leeds                  1
# Delhi                  1
# Chester-le-Street      1
# Wellington             1
# ...

# %%
plt.figure(figsize=(17,7))
Australia.Ground.value_counts().plot(kind='bar')
plt.title('Most Matches Played On Each Venue',fontsize=20)
plt.xlabel('Venue',fontsize=15);

# %%
plt.figure(figsize=(17,7))
data.Ground.value_counts().plot(kind='bar')
plt.xlabel('Venue',fontsize=15);

# %%
Australia[Australia.Target>400].Result.value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(9,6))
Australia[Australia.Result=='won'].Ground.value_counts().plot(kind='bar')
plt.title('Most Wins On Each Venus')
plt.xlabel('Venus');

# %% [markdown]
# # England Team Data

# %%
England_players=players[players['Country']=="England"]

# %%
England_players
# Out:
#                   Player      ID  Country
# 46       Eoin Morgan (c)   24598  England
# 47  Jos Buttler (vc, wk)  308967  England
# 48             Moeen Ali    8917  England
# 49        Jonny Bairstow  297433  England
# 50            Tom Curran  550235  England
# 51             Joe Denly   12454  England
# 52            Alex Hales  249866  England
# 53         Liam Plunkett   19264  England
# 54           Adil Rashid  244497  England
# 55              Joe Root  303669  England
# 56             Jason Roy  298438  England
# 57            Ben Stokes  311158  England
# 58          David Willey  308251  England
# 59          Chris Woakes  247235  England
# 60             Mark Wood  351588  England

# %%
England = odi_total[odi_total['Country']=='England']
England
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result  Opposition  \
# 7            836  325/4   50.0  6.50     NaN     1    won     v India
# 11           837    158   36.0  4.38   286.0     2   lost     v India
# 15           838    155   42.2  3.66     NaN     1   lost     v India
# 25           839  257/7   50.0  5.14     NaN     1   lost     v India
# 29           840  227/3   47.2  4.79   227.0     2    won     v India
# ...          ...    ...    ...   ...     ...   ...    ...         ...
# 1279         976    DNB    0.0     -     NaN     0    n/r  v Pakistan
# 1283         977  373/3   50.0  7.46     NaN     1    won  v Pakistan
# 1287         978  359/4   44.5  8.00   359.0     2    won  v Pakistan
# 1292         979  341/7   49.3  6.88   341.0     2    won  v Pakistan
# 1295         980  351/9   50.0  7.02     NaN     1      -  v Pakistan
#
#            Ground   Start Date    Match_ID  Country  Country_ID
# ...

# %%
England_win = England[England['Result']=='won']

# %%
England_win['Opposition'].value_counts()
# Out:
# v Australia       15
# v West Indies     11
# v New Zealand     11
# v Sri Lanka       10
# v Pakistan        10
# v India            8
# v South Africa     5
# v Ireland          4
# v Bangladesh       3
# v Scotland         2
# v Afghanistan      1
# Name: Opposition, dtype: int64

# %%
plt.figure(figsize=(10,5))
England_win['Opposition'].value_counts().plot(kind='bar')
plt.title('Most wins Against Respective Teams',fontsize=20)
plt.xlabel('Team');

# %%
England_lose = England[England['Result']=='lost']

# %%
England_lose['Opposition'].value_counts()
# Out:
# v Australia       14
# v Sri Lanka       11
# v India           10
# v New Zealand      8
# v South Africa     4
# v West Indies      3
# v Pakistan         3
# v Bangladesh       2
# v Scotland         1
# Name: Opposition, dtype: int64

# %%
plt.figure(figsize=(10,5))
England_lose['Opposition'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.xlabel('Team');

# %%
England[England.Target>250]
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 11           837    158   36.0  4.38   286.0     2   lost         v India
# 43           842  270/2   47.4  5.66   270.0     2    won   v New Zealand
# 77           845    273   44.1  6.18   360.0     2   lost   v New Zealand
# 152          852  274/4   43.0  6.37   270.0     2    won       v Ireland
# 154          853    227   44.2  5.12   316.0     2   lost     v Australia
# 160          856    249   48.0  5.18   299.0     2   lost     v Australia
# 270          862  254/6   50.0  5.08   270.0     2   lost   v West Indies
# 296          867     99   26.1  3.78   257.0     2   lost     v Sri Lanka
# 300          869  293/8   50.0  5.86   301.0     2   lost     v Sri Lanka
# 336          871    161   38.1  4.21   295.0     2   lost         v India
# 394          875    292   47.1  6.19   318.0     2   lost     v Sri Lanka
# 414          880    202   41.3  4.86   293.0     2   lost     v Sri Lanka
# ...

# %%
England[England.Target>250].Result.value_counts()
# Out:
# lost    21
# won     19
# tied     1
# Name: Result, dtype: int64

# %%
plt.figure(figsize=(8,5))
England[England.Target>250].Result.value_counts().plot(kind='bar')
plt.title('Matches Won While Chasing 250+ Score');

# %%
England.Ground.value_counts()
# Out:
# The Oval             9
# Nottingham           9
# Southampton          8
# Birmingham           8
# Cardiff              8
# Lord's               7
# Leeds                6
# Manchester           6
# North Sound          5
# Colombo (RPS)        5
# Sydney               4
# Perth                4
# Bristol              4
# Pallekele            4
# Wellington           3
# Adelaide             3
# Bridgetown           3
# Chester-le-Street    3
# Dublin (Malahide)    3
# Brisbane             3
# Melbourne            3
# Hamilton             2
# Dhaka                2
# St George's          2
# Dambulla             2
# Abu Dhabi            2
# Christchurch         2
# Aberdeen             1
# Chattogram           1
# Cuttack              1
# Edinburgh            1
# Dunedin              1
# Cape Town            1
# Johannesburg         1
# Hambantota           1
# Dubai (DSC)          1
# Napier               1
# Hobart               1
# Pune                 1
# Kolkata              1
# ...

# %%
plt.figure(figsize=(17,7))
England.Ground.value_counts().plot(kind='bar')
plt.title('Most Matches Played On Each Venue',fontsize=20)
plt.xlabel('Venue',fontsize=15);

# %%
England[England.Target>400] # England got 400+ Target to chase
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Score, Overs, RPO, Target, Inns, Result, Opposition, Ground, Start Date, Match_ID, Country, Country_ID]
# Index: []

# %%
plt.figure(figsize=(9,6))
England[England.Result=='won'].Ground.value_counts().plot(kind='bar')
plt.title('Most Wins On Each Venus')
plt.xlabel('Venus');
